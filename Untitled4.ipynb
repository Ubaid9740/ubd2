# %%
wds="""In today's interconnected world, a myriad of topics shapes our understanding of society, technology, culture, and the natural world.
This text embarks on a journey through these diverse subjects, offering insights into their significance and interplay.
The advent of the digital age has revolutionized communication, commerce, and entertainment.
From the rise of social media to the impact of artificial intelligence, technology permeates every aspect of modern life, shaping how we work, interact, and perceive the world around us.
Climate change poses one of the most pressing challenges of our time, threatening ecosystems, communities, and global stability. Addressing this crisis requires collective action, innovation, and a renewed commitment to sustainability practices that mitigate environmental degradation and promote resilience.
Cultural diversity enriches societies, fostering creativity, dialogue, and mutual understanding.
Exploring different cultures, languages, and traditions broadens our perspectives and deepens our appreciation for the richness of human experience, while also highlighting the importance of respecting and preserving cultural heritage.
Health and wellness are integral to quality of life, encompassing physical, mental, and emotional well-being.
From preventive medicine to holistic approaches to healing, individuals and communities strive to achieve optimal health through lifestyle choices, healthcare access, and support systems that prioritize holistic wellness.
Globalization has interconnected economies, markets, and supply chains, shaping global trade, investment, and development.
While fostering economic growth and innovation, globalization also presents challenges such as income inequality, labor exploitation, and geopolitical tensions, underscoring the need for inclusive and sustainable economic practices.
Education is the cornerstone of personal growth, social mobility, and societal progress.
Lifelong learning empowers individuals to adapt to change, acquire new skills, and pursue their passions, while also promoting critical thinking, creativity, and informed citizenship in an increasingly complex world.
Ethical dilemmas confront individuals and societies with complex questions of right and wrong, justice and fairness, and the ethical implications of technological advancements, scientific discoveries, and social norms.
Moral philosophy provides frameworks for ethical reasoning and decision-making, guiding ethical behavior and fostering moral responsibility.
Art and creativity transcend boundaries, inspiring imagination, empathy, and social change.
From visual arts to literature, music, and performance, creative expression enriches human experience, fosters cultural dialogue, and challenges perceptions, reflecting the diversity and complexity of the human spirit.
As we navigate the complexities of our interconnected world, embracing diverse topics broadens our horizons, fosters curiosity, and encourages dialogue and collaboration across disciplines and cultures.
By exploring these diverse subjects, we gain deeper insights into the challenges and opportunities that shape our shared future, empowering us to make informed decisions and create positive change in the world.
At the forefront of scientific inquiry lies the boundless expanse of the cosmos, a realm of wonder and fascination that has captivated the human imagination for millennia.
From the swirling galaxies to the enigmatic black holes, the universe presents a tapestry of celestial marvels waiting to be discovered.
The study of astronomy allows us to peer into the depths of space, unraveling the secrets of distant stars and galaxies.
Through telescopes and space probes, astronomers observe cosmic phenomena, seeking to understand the origins and evolution of the universe.
From the birth of stars in nebulae to the cataclysmic explosions of supernovae, each cosmic event offers clues to the cosmic drama unfolding across billions of years.
While the cosmos may span the reaches of space, another frontier of exploration lies within the confines of the human mind.
Psychology, the science of behavior and mental processes, delves into the complexities of human consciousness, emotion, and cognition.
From the intricate workings of the brain to the dynamics of social interaction, psychology explores the myriad factors that shape human behavior.
Through experiments, observations, and clinical studies, psychologists uncover the mechanisms underlying phenomena such as memory, perception, motivation, and personality.
In the modern age, the digital landscape has emerged as a new frontier of exploration, offering boundless opportunities for innovation and discovery.
From the rise of artificial intelligence to the proliferation of virtual reality, technology continues to reshape the way we interact with the world around us.
In the realm of artificial intelligence (AI), researchers seek to create machines capable of emulating human intelligence and reasoning.
Through techniques such as machine learning and neural networks, AI systems can analyze vast amounts of data, recognize patterns, and make decisions with increasing autonomy.
From self-driving cars to virtual assistants, AI technologies are transforming industries and revolutionizing the way we live and work.
Amidst the rapid pace of technological advancement, the preservation of the natural world remains a critical concern for humanity.
Environmental science, the study of the Earth's ecosystems and the impact of human activity, seeks to understand the delicate balance of nature and safeguard the planet for future generations.
From the lush rainforests to the expansive oceans, Earth is home to a rich diversity of life forms, each playing a vital role in maintaining the health of the planet.
Environmental scientists study ecosystems, monitor pollution levels, and develop conservation strategies to mitigate the effects of climate change, habitat destruction, and pollution.
In the field of medicine, researchers are constantly pushing the boundaries of knowledge and innovation, seeking new treatments and cures for a myriad of diseases and conditions.
From the microscopic world of genetics to the cutting-edge realm of biotechnology, medical science offers hope for improved health and longevity.
Genomics, the study of the human genome, has revolutionized our understanding of genetics and hereditary diseases.
By mapping the human genome and deciphering the genetic code, scientists can identify genes associated with various diseases and develop targeted therapies tailored to individual patients."""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
wds=wds.lower()
tokenizer=Tokenizer()
tokenizer.fit_on_texts([wds])

# %%
len(tokenizer.word_index)
# Out:
# 457

# %%
input_sequence=[]
for scentence in wds.split('.'):
  if scentence != '':
   tokenized_scentence=tokenizer.texts_to_sequences([scentence])[0]
   for i in range(1,len(tokenized_scentence)):
    input_sequence.append(tokenized_scentence[:i+1])

# %%
input_sequence
# Out:
# [[10, 138],
#  [10, 138, 29],
#  [10, 138, 29, 8],
#  [10, 138, 29, 8, 6],
#  [10, 138, 29, 8, 6, 30],
#  [10, 138, 29, 8, 6, 30, 3],
#  [10, 138, 29, 8, 6, 30, 3, 55],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3, 140],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3, 140, 32],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3, 140, 32, 141],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3, 140, 32, 141, 2],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3, 140, 32, 141, 2, 1],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3, 140, 32, 141, 2, 1, 56],
#  [10, 138, 29, 8, 6, 30, 3, 55, 139, 11, 31, 3, 140, 32, 141, 2, 1, 56, 8],
#  [57, 142],
#  [57, 142, 143],
#  [57, 142, 143, 144],
#  [57, 142, 143, 144, 6],
#  [57, 142, 143, 144, 6, 145],
#  [57, 142, 143, 144, 6, 145, 12],
#  [57, 142, 143, 144, 6, 145, 12, 58],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59, 60],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59, 60, 61],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59, 60, 61, 19],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59, 60, 61, 19, 62],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59, 60, 61, 19, 62, 146],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59, 60, 61, 19, 62, 146, 2],
#  [57, 142, 143, 144, 6, 145, 12, 58, 33, 59, 60, 61, 19, 62, 146, 2, 147],
#  [1, 148],
#  [1, 148, 3],
#  [1, 148, 3, 1],
#  [1, 148, 3, 1, 63],
#  [1, 148, 3, 1, 63, 64],
#  [1, 148, 3, 1, 63, 64, 13],
#  [1, 148, 3, 1, 63, 64, 13, 65],
#  [1, 148, 3, 1, 63, 64, 13, 65, 149],
#  [1, 148, 3, 1, 63, 64, 13, 65, 149, 150],
#  [1, 148, 3, 1, 63, 64, 13, 65, 149, 150, 2],
#  [1, 148, 3, 1, 63, 64, 13, 65, 149, 150, 2, 151],
#  [7, 1],
#  [7, 1, 66],
#  [7, 1, 66, 3],
#  [7, 1, 66, 3, 14],
#  [7, 1, 66, 3, 14, 152],
#  [7, 1, 66, 3, 14, 152, 4],
#  [7, 1, 66, 3, 14, 152, 4, 1],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32, 153],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32, 153, 154],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32, 153, 154, 155],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32, 153, 154, 155, 3],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32, 153, 154, 155, 3, 68],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32, 153, 154, 155, 3, 68, 35],
#  [7, 1, 66, 3, 14, 152, 4, 1, 67, 3, 34, 20, 32, 153, 154, 155, 3, 68, 35, 69],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70,
#   71],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70,
#   71,
#   2],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70,
#   71,
#   2,
#   157],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70,
#   71,
#   2,
#   157,
#   1],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70,
#   71,
#   2,
#   157,
#   1,
#   8],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70,
#   71,
#   2,
#   157,
#   1,
#   8,
#   72],
#  [7,
#   1,
#   66,
#   3,
#   14,
#   152,
#   4,
#   1,
#   67,
#   3,
#   34,
#   20,
#   32,
#   153,
#   154,
#   155,
#   3,
#   68,
#   35,
#   69,
#   156,
#   15,
#   70,
#   71,
#   2,
#   157,
#   1,
#   8,
#   72,
#   21],
#  [73, 16],
#  [73, 16, 158],
#  [73, 16, 158, 159],
#  [73, 16, 158, 159, 3],
#  [73, 16, 158, 159, 3, 1],
#  [73, 16, 158, 159, 3, 1, 160],
#  [73, 16, 158, 159, 3, 1, 160, 161],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11, 162],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11, 162, 163],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11, 162, 163, 36],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11, 162, 163, 36, 74],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11, 162, 163, 36, 74, 2],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11, 162, 163, 36, 74, 2, 75],
#  [73, 16, 158, 159, 3, 1, 160, 161, 22, 3, 11, 162, 163, 36, 74, 2, 75, 164],
#  [165, 57],
#  [165, 57, 166],
#  [165, 57, 166, 167],
#  [165, 57, 166, 167, 168],
#  [165, 57, 166, 167, 168, 169],
#  [165, 57, 166, 167, 168, 169, 23],
#  [165, 57, 166, 167, 168, 169, 23, 2],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170, 171],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170, 171, 4],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170, 171, 4, 172],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170, 171, 4, 172, 76],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170, 171, 4, 172, 76, 17],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170, 171, 4, 172, 76, 17, 77],
#  [165, 57, 166, 167, 168, 169, 23, 2, 6, 170, 171, 4, 172, 76, 17, 77, 37],
#  [165,
#   57,
#   166,
#   167,
#   168,
#   169,
#   23,
#   2,
#   6,
#   170,
#   171,
#   4,
#   172,
#   76,
#   17,
#   77,
#   37,
#   173],
#  [165,
#   57,
#   166,
#   167,
#   168,
#   169,
#   23,
#   2,
#   6,
#   170,
#   171,
#   4,
#   172,
#   76,
#   17,
#   77,
#   37,
#   173,
#   2],
#  [165,
#   57,
#   166,
#   167,
#   168,
#   169,
#   23,
#   2,
#   6,
#   170,
#   171,
#   4,
#   172,
#   76,
#   17,
#   77,
#   37,
#   173,
#   2,
#   174],
#  [165,
#   57,
#   166,
#   167,
#   168,
#   169,
#   23,
#   2,
#   6,
#   170,
#   171,
#   4,
#   172,
#   76,
#   17,
#   77,
#   37,
#   173,
#   2,
#   174,
#   175],
#  [38, 39],
#  [38, 39, 78],
#  [38, 39, 78, 79],
#  [38, 39, 78, 79, 40],
#  [38, 39, 78, 79, 40, 41],
#  [38, 39, 78, 79, 40, 41, 42],
#  [38, 39, 78, 79, 40, 41, 42, 2],
#  [38, 39, 78, 79, 40, 41, 42, 2, 176],
#  [38, 39, 78, 79, 40, 41, 42, 2, 176, 31],
#  [80, 177],
#  [80, 177, 81],
#  [80, 177, 81, 178],
#  [80, 177, 81, 178, 2],
#  [80, 177, 81, 178, 2, 179],
#  [80, 177, 81, 178, 2, 179, 82],
#  [80, 177, 81, 178, 2, 179, 82, 11],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11, 182],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11, 182, 9],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11, 182, 9, 1],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11, 182, 9, 1, 183],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11, 182, 9, 1, 183, 3],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11, 182, 9, 1, 183, 3, 5],
#  [80, 177, 81, 178, 2, 179, 82, 11, 180, 2, 181, 11, 182, 9, 1, 183, 3, 5, 83],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1,
#   185],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1,
#   185,
#   3],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1,
#   185,
#   3,
#   186],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1,
#   185,
#   3,
#   186,
#   2],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1,
#   185,
#   3,
#   186,
#   2,
#   187],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1,
#   185,
#   3,
#   186,
#   2,
#   187,
#   38],
#  [80,
#   177,
#   81,
#   178,
#   2,
#   179,
#   82,
#   11,
#   180,
#   2,
#   181,
#   11,
#   182,
#   9,
#   1,
#   183,
#   3,
#   5,
#   83,
#   24,
#   43,
#   184,
#   1,
#   185,
#   3,
#   186,
#   2,
#   187,
#   38,
#   188],
#  [25, 2],
#  [25, 2, 84],
#  [25, 2, 84, 44],
#  [25, 2, 84, 44, 189],
#  [25, 2, 84, 44, 189, 4],
#  [25, 2, 84, 44, 189, 4, 190],
#  [25, 2, 84, 44, 189, 4, 190, 3],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35, 191],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35, 191, 192],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35, 191, 192, 85],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35, 191, 192, 85, 2],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35, 191, 192, 85, 2, 193],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35, 191, 192, 85, 2, 193, 194],
#  [25, 2, 84, 44, 189, 4, 190, 3, 35, 191, 192, 85, 2, 193, 194, 195],
#  [7, 196],
#  [7, 196, 86],
#  [7, 196, 86, 4],
#  [7, 196, 86, 4, 87],
#  [7, 196, 86, 4, 87, 197],
#  [7, 196, 86, 4, 87, 197, 4],
#  [7, 196, 86, 4, 87, 197, 4, 198],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74, 199],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74, 199, 4],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74, 199, 4, 200],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74, 199, 4, 200, 201],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74, 199, 4, 200, 201, 25],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74, 199, 4, 200, 201, 25, 12],
#  [7, 196, 86, 4, 87, 197, 4, 198, 45, 2, 74, 199, 4, 200, 201, 25, 12, 202],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205,
#   2],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205,
#   2,
#   206],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205,
#   2,
#   206,
#   88],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205,
#   2,
#   206,
#   88,
#   17],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205,
#   2,
#   206,
#   88,
#   17,
#   207],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205,
#   2,
#   206,
#   88,
#   17,
#   207,
#   87],
#  [7,
#   196,
#   86,
#   4,
#   87,
#   197,
#   4,
#   198,
#   45,
#   2,
#   74,
#   199,
#   4,
#   200,
#   201,
#   25,
#   12,
#   202,
#   203,
#   204,
#   205,
#   2,
#   206,
#   88,
#   17,
#   207,
#   87,
#   84],
#  [89, 13],
#  [89, 13, 29],
#  [89, 13, 29, 208],
#  [89, 13, 29, 208, 209],
#  [89, 13, 29, 208, 209, 2],
#  [89, 13, 29, 208, 209, 2, 210],
#  [89, 13, 29, 208, 209, 2, 210, 211],
#  [89, 13, 29, 208, 209, 2, 210, 211, 69],
#  [89, 13, 29, 208, 209, 2, 210, 211, 69, 75],
#  [89, 13, 29, 208, 209, 2, 210, 211, 69, 75, 212],
#  [89, 13, 29, 208, 209, 2, 210, 211, 69, 75, 212, 213],
#  [89, 13, 29, 208, 209, 2, 210, 211, 69, 75, 212, 213, 2],
#  [89, 13, 29, 208, 209, 2, 210, 211, 69, 75, 212, 213, 2, 214],
#  [24, 40],
#  [24, 40, 90],
#  [24, 40, 90, 91],
#  [24, 40, 90, 91, 2],
#  [24, 40, 90, 91, 2, 23],
#  [24, 40, 90, 91, 2, 23, 89],
#  [24, 40, 90, 91, 2, 23, 89, 43],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46, 18],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46, 18, 215],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46, 18, 215, 216],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46, 18, 215, 216, 217],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46, 18, 215, 216, 217, 218],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46, 18, 215, 216, 217, 218, 2],
#  [24, 40, 90, 91, 2, 23, 89, 43, 92, 22, 46, 18, 215, 216, 217, 218, 2, 219],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1,
#   222],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1,
#   222,
#   9],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1,
#   222,
#   9,
#   223],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1,
#   222,
#   9,
#   223,
#   2],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1,
#   222,
#   9,
#   223,
#   2,
#   224],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1,
#   222,
#   9,
#   223,
#   2,
#   224,
#   90],
#  [24,
#   40,
#   90,
#   91,
#   2,
#   23,
#   89,
#   43,
#   92,
#   22,
#   46,
#   18,
#   215,
#   216,
#   217,
#   218,
#   2,
#   219,
#   220,
#   221,
#   1,
#   222,
#   9,
#   223,
#   2,
#   224,
#   90,
#   76],
#  [225, 93],
#  [225, 93, 1],
#  [225, 93, 1, 226],
#  [225, 93, 1, 226, 3],
#  [225, 93, 1, 226, 3, 227],
#  [225, 93, 1, 226, 3, 227, 91],
#  [225, 93, 1, 226, 3, 227, 91, 14],
#  [225, 93, 1, 226, 3, 227, 91, 14, 228],
#  [225, 93, 1, 226, 3, 227, 91, 14, 228, 2],
#  [225, 93, 1, 226, 3, 227, 91, 14, 228, 2, 229],
#  [225, 93, 1, 226, 3, 227, 91, 14, 228, 2, 229, 230],
#  [231, 94],
#  [231, 94, 232],
#  [231, 94, 232, 45],
#  [231, 94, 232, 45, 4],
#  [231, 94, 232, 45, 4, 233],
#  [231, 94, 232, 45, 4, 233, 4],
#  [231, 94, 232, 45, 4, 233, 4, 16],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235, 2],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235, 2, 236],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235, 2, 236, 62],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235, 2, 236, 62, 237],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235, 2, 236, 62, 237, 24],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235, 2, 236, 62, 237, 24, 43],
#  [231, 94, 232, 45, 4, 233, 4, 16, 234, 47, 235, 2, 236, 62, 237, 24, 43, 238],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2,
#   96],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2,
#   96,
#   240],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2,
#   96,
#   240,
#   10],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2,
#   96,
#   240,
#   10,
#   241],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2,
#   96,
#   240,
#   10,
#   241,
#   242],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2,
#   96,
#   240,
#   10,
#   241,
#   242,
#   97],
#  [231,
#   94,
#   232,
#   45,
#   4,
#   233,
#   4,
#   16,
#   234,
#   47,
#   235,
#   2,
#   236,
#   62,
#   237,
#   24,
#   43,
#   238,
#   95,
#   239,
#   41,
#   2,
#   96,
#   240,
#   10,
#   241,
#   242,
#   97,
#   8],
#  [26, 243],
#  [26, 243, 244],
#  [26, 243, 244, 45],
#  [26, 243, 244, 45, 2],
#  [26, 243, 244, 45, 2, 79],
#  [26, 243, 244, 45, 2, 79, 27],
#  [26, 243, 244, 45, 2, 79, 27, 97],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2, 247],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2, 247, 248],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2, 247, 248, 2],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2, 247, 248, 2, 249],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2, 247, 248, 2, 249, 2],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2, 247, 248, 2, 249, 2, 1],
#  [26, 243, 244, 45, 2, 79, 27, 97, 245, 3, 246, 2, 247, 248, 2, 249, 2, 1, 26],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3,
#   98],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3,
#   98,
#   251],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3,
#   98,
#   251,
#   99],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3,
#   98,
#   251,
#   99,
#   252],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3,
#   98,
#   251,
#   99,
#   252,
#   2],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3,
#   98,
#   251,
#   99,
#   252,
#   2,
#   14],
#  [26,
#   243,
#   244,
#   45,
#   2,
#   79,
#   27,
#   97,
#   245,
#   3,
#   246,
#   2,
#   247,
#   248,
#   2,
#   249,
#   2,
#   1,
#   26,
#   250,
#   3,
#   98,
#   251,
#   99,
#   252,
#   2,
#   14,
#   253],
#  [100, 254],
#  [100, 254, 255],
#  [100, 254, 255, 256],
#  [100, 254, 255, 256, 9],
#  [100, 254, 255, 256, 9, 26],
#  [100, 254, 255, 256, 9, 26, 101],
#  [100, 254, 255, 256, 9, 26, 101, 2],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258, 259],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258, 259, 26],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258, 259, 26, 48],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258, 259, 26, 48, 2],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258, 259, 26, 48, 2, 40],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258, 259, 26, 48, 2, 40, 100],
#  [100, 254, 255, 256, 9, 26, 101, 2, 257, 258, 259, 26, 48, 2, 40, 100, 260],
#  [261, 2],
#  [261, 2, 41],
#  [261, 2, 41, 262],
#  [261, 2, 41, 262, 102],
#  [261, 2, 41, 262, 102, 263],
#  [261, 2, 41, 262, 102, 263, 103],
#  [261, 2, 41, 262, 102, 263, 103, 264],
#  [261, 2, 41, 262, 102, 263, 103, 264, 2],
#  [261, 2, 41, 262, 102, 263, 103, 264, 2, 14],
#  [261, 2, 41, 262, 102, 263, 103, 264, 2, 14, 16],
#  [7, 265],
#  [7, 265, 266],
#  [7, 265, 266, 4],
#  [7, 265, 266, 4, 267],
#  [7, 265, 266, 4, 267, 268],
#  [7, 265, 266, 4, 267, 268, 2],
#  [7, 265, 266, 4, 267, 268, 2, 269],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78, 5],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78, 5, 83],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78, 5, 83, 104],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78, 5, 83, 104, 38],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78, 5, 83, 104, 38, 42],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78, 5, 83, 104, 38, 42, 2],
#  [7, 265, 266, 4, 267, 268, 2, 269, 270, 271, 78, 5, 83, 104, 38, 42, 2, 22],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1,
#   39],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1,
#   39,
#   2],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1,
#   39,
#   2,
#   274],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1,
#   39,
#   2,
#   274,
#   3],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1,
#   39,
#   2,
#   274,
#   3,
#   1],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1,
#   39,
#   2,
#   274,
#   3,
#   1,
#   5],
#  [7,
#   265,
#   266,
#   4,
#   267,
#   268,
#   2,
#   269,
#   270,
#   271,
#   78,
#   5,
#   83,
#   104,
#   38,
#   42,
#   2,
#   22,
#   272,
#   273,
#   1,
#   39,
#   2,
#   274,
#   3,
#   1,
#   5,
#   275],
#  [18, 15],
#  [18, 15, 276],
#  [18, 15, 276, 1],
#  [18, 15, 276, 1, 105],
#  [18, 15, 276, 1, 105, 3],
#  [18, 15, 276, 1, 105, 3, 11],
#  [18, 15, 276, 1, 105, 3, 11, 29],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33, 55],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33, 55, 82],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33, 55, 82, 11],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33, 55, 82, 11, 278],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33, 55, 82, 11, 278, 104],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33, 55, 82, 11, 278, 104, 279],
#  [18, 15, 276, 1, 105, 3, 11, 29, 8, 277, 33, 55, 82, 11, 278, 104, 279, 2],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280,
#   42],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280,
#   42,
#   2],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280,
#   42,
#   2,
#   281],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280,
#   42,
#   2,
#   281,
#   106],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280,
#   42,
#   2,
#   281,
#   106,
#   282],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280,
#   42,
#   2,
#   281,
#   106,
#   282,
#   2],
#  [18,
#   15,
#   276,
#   1,
#   105,
#   3,
#   11,
#   29,
#   8,
#   277,
#   33,
#   55,
#   82,
#   11,
#   278,
#   104,
#   279,
#   2,
#   280,
#   42,
#   2,
#   281,
#   106,
#   282,
#   2,
#   81],
#  [107, 80],
#  [107, 80, 58],
#  [107, 80, 58, 33],
#  [107, 80, 58, 33, 59],
#  [107, 80, 58, 33, 59, 15],
#  [107, 80, 58, 33, 59, 15, 283],
#  [107, 80, 58, 33, 59, 15, 283, 284],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1, 22],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1, 22, 2],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1, 22, 2, 108],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1, 22, 2, 108, 17],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1, 22, 2, 108, 17, 109],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1, 22, 2, 108, 17, 109, 11],
#  [107, 80, 58, 33, 59, 15, 283, 284, 61, 19, 1, 22, 2, 108, 17, 109, 11, 285],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112,
#   2],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112,
#   2,
#   113],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112,
#   2,
#   113,
#   287],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112,
#   2,
#   113,
#   287,
#   16],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112,
#   2,
#   113,
#   287,
#   16,
#   10],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112,
#   2,
#   113,
#   287,
#   16,
#   10,
#   1],
#  [107,
#   80,
#   58,
#   33,
#   59,
#   15,
#   283,
#   284,
#   61,
#   19,
#   1,
#   22,
#   2,
#   108,
#   17,
#   109,
#   11,
#   285,
#   110,
#   286,
#   21,
#   4,
#   111,
#   96,
#   112,
#   2,
#   113,
#   287,
#   16,
#   10,
#   1,
#   8],
#  [288, 1],
#  [288, 1, 289],
#  [288, 1, 289, 3],
#  [288, 1, 289, 3, 99],
#  [288, 1, 289, 3, 99, 290],
#  [288, 1, 289, 3, 99, 290, 114],
#  [288, 1, 289, 3, 99, 290, 114, 1],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1, 116],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1, 116, 6],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1, 116, 6, 49],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1, 116, 6, 49, 3],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1, 116, 6, 49, 3, 292],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1, 116, 6, 49, 3, 292, 2],
#  [288, 1, 289, 3, 99, 290, 114, 1, 115, 291, 3, 1, 116, 6, 49, 3, 292, 2, 293],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17,
#   13],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17,
#   13,
#   294],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17,
#   13,
#   294,
#   1],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17,
#   13,
#   294,
#   1,
#   5],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17,
#   13,
#   294,
#   1,
#   5,
#   103],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17,
#   13,
#   294,
#   1,
#   5,
#   103,
#   9],
#  [288,
#   1,
#   289,
#   3,
#   99,
#   290,
#   114,
#   1,
#   115,
#   291,
#   3,
#   1,
#   116,
#   6,
#   49,
#   3,
#   292,
#   2,
#   293,
#   17,
#   13,
#   294,
#   1,
#   5,
#   103,
#   9,
#   295],
#  [7, 1],
#  [7, 1, 296],
#  [7, 1, 296, 117],
#  [7, 1, 296, 117, 4],
#  [7, 1, 296, 117, 4, 1],
#  [7, 1, 296, 117, 4, 1, 297],
#  [7, 1, 296, 117, 4, 1, 297, 298],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118, 92],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118, 92, 6],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118, 92, 6, 300],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118, 92, 6, 300, 3],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118, 92, 6, 300, 3, 301],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118, 92, 6, 300, 3, 301, 302],
#  [7, 1, 296, 117, 4, 1, 297, 298, 299, 1, 118, 92, 6, 300, 3, 301, 302, 303],
#  [7,
#   1,
#   296,
#   117,
#   4,
#   1,
#   297,
#   298,
#   299,
#   1,
#   118,
#   92,
#   6,
#   300,
#   3,
#   301,
#   302,
#   303,
#   4],
#  [7,
#   1,
#   296,
#   117,
#   4,
#   1,
#   297,
#   298,
#   299,
#   1,
#   118,
#   92,
#   6,
#   300,
#   3,
#   301,
#   302,
#   303,
#   4,
#   304],
#  [7,
#   1,
#   296,
#   117,
#   4,
#   1,
#   297,
#   298,
#   299,
#   1,
#   118,
#   92,
#   6,
#   300,
#   3,
#   301,
#   302,
#   303,
#   4,
#   304,
#   305],
#  [1, 28],
#  [1, 28, 3],
#  [1, 28, 3, 306],
#  [1, 28, 3, 306, 307],
#  [1, 28, 3, 306, 307, 21],
#  [1, 28, 3, 306, 307, 21, 4],
#  [1, 28, 3, 306, 307, 21, 4, 308],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3, 50],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3, 50, 310],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3, 50, 310, 1],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3, 50, 310, 1, 311],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3, 50, 310, 1, 311, 3],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3, 50, 310, 1, 311, 3, 312],
#  [1, 28, 3, 306, 307, 21, 4, 308, 19, 1, 309, 3, 50, 310, 1, 311, 3, 312, 119],
#  [1,
#   28,
#   3,
#   306,
#   307,
#   21,
#   4,
#   308,
#   19,
#   1,
#   309,
#   3,
#   50,
#   310,
#   1,
#   311,
#   3,
#   312,
#   119,
#   2],
#  [1,
#   28,
#   3,
#   306,
#   307,
#   21,
#   4,
#   308,
#   19,
#   1,
#   309,
#   3,
#   50,
#   310,
#   1,
#   311,
#   3,
#   312,
#   119,
#   2,
#   117],
#  [12, 313],
#  [12, 313, 2],
#  [12, 313, 2, 50],
#  [12, 313, 2, 50, 314],
#  [12, 313, 2, 50, 314, 315],
#  [12, 313, 2, 50, 314, 315, 316],
#  [12, 313, 2, 50, 314, 315, 316, 51],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4, 122],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4, 122, 1],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4, 122, 1, 317],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4, 122, 1, 317, 2],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4, 122, 1, 317, 2, 318],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4, 122, 1, 317, 2, 318, 3],
#  [12, 313, 2, 50, 314, 315, 316, 51, 120, 121, 4, 122, 1, 317, 2, 318, 3, 1],
#  [12,
#   313,
#   2,
#   50,
#   314,
#   315,
#   316,
#   51,
#   120,
#   121,
#   4,
#   122,
#   1,
#   317,
#   2,
#   318,
#   3,
#   1,
#   118],
#  [7, 1],
#  [7, 1, 319],
#  [7, 1, 319, 3],
#  [7, 1, 319, 3, 119],
#  [7, 1, 319, 3, 119, 10],
#  [7, 1, 319, 3, 119, 10, 320],
#  [7, 1, 319, 3, 119, 10, 320, 4],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322, 3],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322, 3, 323],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322, 3, 323, 123],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322, 3, 323, 123, 51],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322, 3, 323, 123, 51, 324],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322, 3, 323, 123, 51, 324, 124],
#  [7, 1, 319, 3, 119, 10, 320, 4, 1, 321, 322, 3, 323, 123, 51, 324, 124, 325],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1,
#   51],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1,
#   51,
#   326],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1,
#   51,
#   326,
#   327],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1,
#   51,
#   326,
#   327,
#   106],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1,
#   51,
#   326,
#   327,
#   106,
#   328],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1,
#   51,
#   326,
#   327,
#   106,
#   328,
#   3],
#  [7,
#   1,
#   319,
#   3,
#   119,
#   10,
#   320,
#   4,
#   1,
#   321,
#   322,
#   3,
#   323,
#   123,
#   51,
#   324,
#   124,
#   325,
#   4,
#   1,
#   51,
#   326,
#   327,
#   106,
#   328,
#   3,
#   329],
#  [24, 1],
#  [24, 1, 116],
#  [24, 1, 116, 330],
#  [24, 1, 116, 330, 331],
#  [24, 1, 116, 330, 331, 1],
#  [24, 1, 116, 330, 331, 1, 332],
#  [24, 1, 116, 330, 331, 1, 332, 3],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125, 3],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125, 3, 126],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125, 3, 126, 114],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125, 3, 126, 114, 334],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125, 3, 126, 114, 334, 1],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125, 3, 126, 114, 334, 1, 335],
#  [24, 1, 116, 330, 331, 1, 332, 3, 50, 333, 125, 3, 126, 114, 334, 1, 335, 3],
#  [24,
#   1,
#   116,
#   330,
#   331,
#   1,
#   332,
#   3,
#   50,
#   333,
#   125,
#   3,
#   126,
#   114,
#   334,
#   1,
#   335,
#   3,
#   1],
#  [24,
#   1,
#   116,
#   330,
#   331,
#   1,
#   332,
#   3,
#   50,
#   333,
#   125,
#   3,
#   126,
#   114,
#   334,
#   1,
#   335,
#   3,
#   1,
#   5],
#  [24,
#   1,
#   116,
#   330,
#   331,
#   1,
#   332,
#   3,
#   50,
#   333,
#   125,
#   3,
#   126,
#   114,
#   334,
#   1,
#   335,
#   3,
#   1,
#   5,
#   336],
#  [127, 1],
#  [127, 1, 52],
#  [127, 1, 52, 3],
#  [127, 1, 52, 3, 48],
#  [127, 1, 52, 3, 48, 2],
#  [127, 1, 52, 3, 48, 2, 85],
#  [127, 1, 52, 3, 48, 2, 85, 337],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1, 105],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1, 105, 3],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1, 105, 3, 5],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1, 105, 3, 5, 339],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1, 105, 3, 5, 339, 340],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1, 105, 3, 5, 339, 340, 2],
#  [127, 1, 52, 3, 48, 2, 85, 337, 338, 19, 1, 105, 3, 5, 339, 340, 2, 341],
#  [7, 1],
#  [7, 1, 342],
#  [7, 1, 342, 343],
#  [7, 1, 342, 343, 3],
#  [7, 1, 342, 343, 3, 1],
#  [7, 1, 342, 343, 3, 1, 344],
#  [7, 1, 342, 343, 3, 1, 344, 4],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14, 346],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14, 346, 127],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14, 346, 127, 347],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14, 346, 127, 347, 1],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14, 346, 127, 347, 1, 30],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14, 346, 127, 347, 1, 30, 348],
#  [7, 1, 342, 343, 3, 1, 344, 4, 1, 345, 3, 14, 346, 127, 347, 1, 30, 348, 17],
#  [7,
#   1,
#   342,
#   343,
#   3,
#   1,
#   344,
#   4,
#   1,
#   345,
#   3,
#   14,
#   346,
#   127,
#   347,
#   1,
#   30,
#   348,
#   17,
#   109],
#  [7,
#   1,
#   342,
#   343,
#   3,
#   1,
#   344,
#   4,
#   1,
#   345,
#   3,
#   14,
#   346,
#   127,
#   347,
#   1,
#   30,
#   348,
#   17,
#   109,
#   5],
#  [7,
#   1,
#   342,
#   343,
#   3,
#   1,
#   344,
#   4,
#   1,
#   345,
#   3,
#   14,
#   346,
#   127,
#   347,
#   1,
#   30,
#   348,
#   17,
#   109,
#   5,
#   48],
#  [12, 349],
#  [12, 349, 350],
#  [12, 349, 350, 2],
#  [12, 349, 350, 2, 351],
#  [12, 349, 350, 2, 351, 352],
#  [12, 349, 350, 2, 351, 352, 353],
#  [12, 349, 350, 2, 351, 352, 353, 354],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1, 355],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1, 355, 356],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1, 355, 356, 120],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1, 355, 356, 120, 46],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1, 355, 356, 120, 46, 18],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1, 355, 356, 120, 46, 18, 357],
#  [12, 349, 350, 2, 351, 352, 353, 354, 1, 355, 356, 120, 46, 18, 357, 358],
#  [12,
#   349,
#   350,
#   2,
#   351,
#   352,
#   353,
#   354,
#   1,
#   355,
#   356,
#   120,
#   46,
#   18,
#   357,
#   358,
#   359],
#  [12,
#   349,
#   350,
#   2,
#   351,
#   352,
#   353,
#   354,
#   1,
#   355,
#   356,
#   120,
#   46,
#   18,
#   357,
#   358,
#   359,
#   2],
#  [12,
#   349,
#   350,
#   2,
#   351,
#   352,
#   353,
#   354,
#   1,
#   355,
#   356,
#   120,
#   46,
#   18,
#   357,
#   358,
#   359,
#   2,
#   360],
#  [10, 1],
#  [10, 1, 68],
#  [10, 1, 68, 64],
#  [10, 1, 68, 64, 1],
#  [10, 1, 68, 64, 1, 63],
#  [10, 1, 68, 64, 1, 63, 361],
#  [10, 1, 68, 64, 1, 63, 361, 13],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47, 125],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47, 125, 3],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47, 125, 3, 126],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47, 125, 3, 126, 60],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47, 125, 3, 126, 60, 115],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47, 125, 3, 126, 60, 115, 108],
#  [10, 1, 68, 64, 1, 63, 361, 13, 362, 18, 6, 47, 125, 3, 126, 60, 115, 108, 9],
#  [10,
#   1,
#   68,
#   64,
#   1,
#   63,
#   361,
#   13,
#   362,
#   18,
#   6,
#   47,
#   125,
#   3,
#   126,
#   60,
#   115,
#   108,
#   9,
#   23],
#  [10,
#   1,
#   68,
#   64,
#   1,
#   63,
#   361,
#   13,
#   362,
#   18,
#   6,
#   47,
#   125,
#   3,
#   126,
#   60,
#   115,
#   108,
#   9,
#   23,
#   2],
#  [10,
#   1,
#   68,
#   64,
#   1,
#   63,
#   361,
#   13,
#   362,
#   18,
#   6,
#   47,
#   125,
#   3,
#   126,
#   60,
#   115,
#   108,
#   9,
#   23,
#   2,
#   363],
#  [7, 1],
#  [7, 1, 66],
#  [7, 1, 66, 3],
#  [7, 1, 66, 3, 34],
#  [7, 1, 66, 3, 34, 20],
#  [7, 1, 66, 3, 34, 20, 4],
#  [7, 1, 66, 3, 34, 20, 4, 1],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365, 32],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365, 32, 366],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365, 32, 366, 4],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365, 32, 366, 4, 367],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365, 32, 366, 4, 367, 1],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365, 32, 366, 4, 367, 1, 129],
#  [7, 1, 66, 3, 34, 20, 4, 1, 364, 3, 128, 365, 32, 366, 4, 367, 1, 129, 15],
#  [7,
#   1,
#   66,
#   3,
#   34,
#   20,
#   4,
#   1,
#   364,
#   3,
#   128,
#   365,
#   32,
#   366,
#   4,
#   367,
#   1,
#   129,
#   15,
#   71],
#  [7,
#   1,
#   66,
#   3,
#   34,
#   20,
#   4,
#   1,
#   364,
#   3,
#   128,
#   365,
#   32,
#   366,
#   4,
#   367,
#   1,
#   129,
#   15,
#   71,
#   27],
#  [7,
#   1,
#   66,
#   3,
#   34,
#   20,
#   4,
#   1,
#   364,
#   3,
#   128,
#   365,
#   32,
#   366,
#   4,
#   367,
#   1,
#   129,
#   15,
#   71,
#   27,
#   1],
#  [7,
#   1,
#   66,
#   3,
#   34,
#   20,
#   4,
#   1,
#   364,
#   3,
#   128,
#   365,
#   32,
#   366,
#   4,
#   367,
#   1,
#   129,
#   15,
#   71,
#   27,
#   1,
#   8],
#  [7,
#   1,
#   66,
#   3,
#   34,
#   20,
#   4,
#   1,
#   364,
#   3,
#   128,
#   365,
#   32,
#   366,
#   4,
#   367,
#   1,
#   129,
#   15,
#   71,
#   27,
#   1,
#   8,
#   72],
#  [7,
#   1,
#   66,
#   3,
#   34,
#   20,
#   4,
#   1,
#   364,
#   3,
#   128,
#   365,
#   32,
#   366,
#   4,
#   367,
#   1,
#   129,
#   15,
#   71,
#   27,
#   1,
#   8,
#   72,
#   21],
#  [10, 1],
#  [10, 1, 49],
#  [10, 1, 49, 3],
#  [10, 1, 49, 3, 34],
#  [10, 1, 49, 3, 34, 20],
#  [10, 1, 49, 3, 34, 20, 53],
#  [10, 1, 49, 3, 34, 20, 53, 130],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369, 370],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369, 370, 3],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369, 370, 3, 371],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369, 370, 3, 371, 5],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369, 370, 3, 371, 5, 20],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369, 370, 3, 371, 5, 20, 2],
#  [10, 1, 49, 3, 34, 20, 53, 130, 368, 4, 113, 369, 370, 3, 371, 5, 20, 2, 101],
#  [12, 372],
#  [12, 372, 46],
#  [12, 372, 46, 18],
#  [12, 372, 46, 18, 373],
#  [12, 372, 46, 18, 373, 94],
#  [12, 372, 46, 18, 373, 94, 2],
#  [12, 372, 46, 18, 373, 94, 2, 374],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53, 88],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53, 88, 131],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53, 88, 131, 376],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53, 88, 131, 376, 377],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53, 88, 131, 376, 377, 378],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53, 88, 131, 376, 377, 378, 3],
#  [12, 372, 46, 18, 373, 94, 2, 374, 375, 53, 88, 131, 376, 377, 378, 3, 379],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380,
#   381],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380,
#   381,
#   2],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380,
#   381,
#   2,
#   111],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380,
#   381,
#   2,
#   111,
#   112],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380,
#   381,
#   2,
#   111,
#   112,
#   27],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380,
#   381,
#   2,
#   111,
#   112,
#   27,
#   382],
#  [12,
#   372,
#   46,
#   18,
#   373,
#   94,
#   2,
#   374,
#   375,
#   53,
#   88,
#   131,
#   376,
#   377,
#   378,
#   3,
#   379,
#   380,
#   381,
#   2,
#   111,
#   112,
#   27,
#   382,
#   383],
#  [7, 384],
#  [7, 384, 385],
#  [7, 384, 385, 386],
#  [7, 384, 385, 386, 4],
#  [7, 384, 385, 386, 4, 128],
#  [7, 384, 385, 386, 4, 128, 387],
#  [7, 384, 385, 386, 4, 128, 387, 53],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44, 389],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44, 389, 390],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44, 389, 390, 2],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44, 389, 390, 2, 391],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44, 389, 390, 2, 391, 1],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44, 389, 390, 2, 391, 1, 129],
#  [7, 384, 385, 386, 4, 128, 387, 53, 388, 44, 389, 390, 2, 391, 1, 129, 15],
#  [7,
#   384,
#   385,
#   386,
#   4,
#   128,
#   387,
#   53,
#   388,
#   44,
#   389,
#   390,
#   2,
#   391,
#   1,
#   129,
#   15,
#   392],
#  [7,
#   384,
#   385,
#   386,
#   4,
#   128,
#   387,
#   53,
#   388,
#   44,
#   389,
#   390,
#   2,
#   391,
#   1,
#   129,
#   15,
#   392,
#   2],
#  [7,
#   384,
#   385,
#   386,
#   4,
#   128,
#   387,
#   53,
#   388,
#   44,
#   389,
#   390,
#   2,
#   391,
#   1,
#   129,
#   15,
#   392,
#   2,
#   70],
#  [393, 1],
#  [393, 1, 394],
#  [393, 1, 394, 395],
#  [393, 1, 394, 395, 3],
#  [393, 1, 394, 395, 3, 98],
#  [393, 1, 394, 395, 3, 98, 396],
#  [393, 1, 394, 395, 3, 98, 396, 1],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56, 8],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56, 8, 398],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56, 8, 398, 6],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56, 8, 398, 6, 95],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56, 8, 398, 6, 95, 399],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56, 8, 398, 6, 95, 399, 9],
#  [393, 1, 394, 395, 3, 98, 396, 1, 397, 3, 1, 56, 8, 398, 6, 95, 399, 9, 400],
#  [37, 52],
#  [37, 52, 1],
#  [37, 52, 1, 28],
#  [37, 52, 1, 28, 3],
#  [37, 52, 1, 28, 3, 1],
#  [37, 52, 1, 28, 3, 1, 401],
#  [37, 52, 1, 28, 3, 1, 401, 36],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5, 402],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5, 402, 403],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5, 402, 403, 4],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5, 402, 403, 4, 122],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5, 402, 403, 4, 122, 1],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5, 402, 403, 4, 122, 1, 404],
#  [37, 52, 1, 28, 3, 1, 401, 36, 2, 1, 67, 3, 5, 402, 403, 4, 122, 1, 404, 405],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406,
#   2],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406,
#   2,
#   407],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406,
#   2,
#   407,
#   1],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406,
#   2,
#   407,
#   1,
#   132],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406,
#   2,
#   407,
#   1,
#   132,
#   9],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406,
#   2,
#   407,
#   1,
#   132,
#   9,
#   110],
#  [37,
#   52,
#   1,
#   28,
#   3,
#   1,
#   401,
#   36,
#   2,
#   1,
#   67,
#   3,
#   5,
#   402,
#   403,
#   4,
#   122,
#   1,
#   404,
#   405,
#   3,
#   406,
#   2,
#   407,
#   1,
#   132,
#   9,
#   110,
#   408],
#  [7, 1],
#  [7, 1, 409],
#  [7, 1, 409, 410],
#  [7, 1, 409, 410, 4],
#  [7, 1, 409, 410, 4, 1],
#  [7, 1, 409, 410, 4, 1, 411],
#  [7, 1, 409, 410, 4, 1, 411, 412],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414, 4],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414, 4, 6],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414, 4, 6, 415],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414, 4, 6, 415, 39],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414, 4, 6, 415, 39, 3],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414, 4, 6, 415, 39, 3, 35],
#  [7, 1, 409, 410, 4, 1, 411, 412, 413, 93, 414, 4, 6, 415, 39, 3, 35, 416],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419,
#   10],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419,
#   10,
#   420],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419,
#   10,
#   420,
#   1],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419,
#   10,
#   420,
#   1,
#   25],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419,
#   10,
#   420,
#   1,
#   25,
#   3],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419,
#   10,
#   420,
#   1,
#   25,
#   3,
#   1],
#  [7,
#   1,
#   409,
#   410,
#   4,
#   1,
#   411,
#   412,
#   413,
#   93,
#   414,
#   4,
#   6,
#   415,
#   39,
#   3,
#   35,
#   416,
#   123,
#   417,
#   6,
#   418,
#   419,
#   10,
#   420,
#   1,
#   25,
#   3,
#   1,
#   132],
#  [37, 133],
#  [37, 133, 28],
#  [37, 133, 28, 36],
#  [37, 133, 28, 36, 421],
#  [37, 133, 28, 36, 421, 134],
#  [37, 133, 28, 36, 421, 134, 422],
#  [37, 133, 28, 36, 421, 134, 422, 2],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424, 4],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424, 4, 77],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424, 4, 77, 1],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424, 4, 77, 1, 425],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424, 4, 77, 1, 425, 3],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424, 4, 77, 1, 425, 3, 73],
#  [37, 133, 28, 36, 421, 134, 422, 2, 135, 423, 424, 4, 77, 1, 425, 3, 73, 16],
#  [37,
#   133,
#   28,
#   36,
#   421,
#   134,
#   422,
#   2,
#   135,
#   423,
#   424,
#   4,
#   77,
#   1,
#   425,
#   3,
#   73,
#   16,
#   426],
#  [37,
#   133,
#   28,
#   36,
#   421,
#   134,
#   422,
#   2,
#   135,
#   423,
#   424,
#   4,
#   77,
#   1,
#   425,
#   3,
#   73,
#   16,
#   426,
#   427],
#  [37,
#   133,
#   28,
#   36,
#   421,
#   134,
#   422,
#   2,
#   135,
#   423,
#   424,
#   4,
#   77,
#   1,
#   425,
#   3,
#   73,
#   16,
#   426,
#   427,
#   2],
#  [37,
#   133,
#   28,
#   36,
#   421,
#   134,
#   422,
#   2,
#   135,
#   423,
#   424,
#   4,
#   77,
#   1,
#   425,
#   3,
#   73,
#   16,
#   426,
#   427,
#   2,
#   134],
#  [10, 1],
#  [10, 1, 428],
#  [10, 1, 428, 3],
#  [10, 1, 428, 3, 86],
#  [10, 1, 428, 3, 86, 130],
#  [10, 1, 428, 3, 86, 130, 44],
#  [10, 1, 428, 3, 86, 130, 44, 429],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102, 3],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102, 3, 431],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102, 3, 431, 2],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102, 3, 431, 2, 23],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102, 3, 431, 2, 23, 121],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102, 3, 431, 2, 23, 121, 47],
#  [10, 1, 428, 3, 86, 130, 44, 429, 430, 1, 102, 3, 431, 2, 23, 121, 47, 432],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433,
#   9],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433,
#   9,
#   6],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433,
#   9,
#   6,
#   30],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433,
#   9,
#   6,
#   30,
#   3],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433,
#   9,
#   6,
#   30,
#   3,
#   54],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433,
#   9,
#   6,
#   30,
#   3,
#   54,
#   2],
#  [10,
#   1,
#   428,
#   3,
#   86,
#   130,
#   44,
#   429,
#   430,
#   1,
#   102,
#   3,
#   431,
#   2,
#   23,
#   121,
#   47,
#   432,
#   2,
#   433,
#   9,
#   6,
#   30,
#   3,
#   54,
#   2,
#   434],
#  [7, 1],
#  [7, 1, 435],
#  [7, 1, 435, 8],
#  [7, 1, 435, 8, 3],
#  [7, 1, 435, 8, 3, 136],
#  [7, 1, 435, 8, 3, 136, 4],
#  [7, 1, 435, 8, 3, 136, 4, 1],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3, 438],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3, 438, 439],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3, 438, 439, 52],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3, 438, 439, 52, 124],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3, 438, 439, 52, 124, 440],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3, 438, 439, 52, 124, 440, 9],
#  [7, 1, 435, 8, 3, 136, 4, 1, 436, 437, 49, 3, 438, 439, 52, 124, 440, 9, 441],
#  [7,
#   1,
#   435,
#   8,
#   3,
#   136,
#   4,
#   1,
#   436,
#   437,
#   49,
#   3,
#   438,
#   439,
#   52,
#   124,
#   440,
#   9,
#   441,
#   25],
#  [7,
#   1,
#   435,
#   8,
#   3,
#   136,
#   4,
#   1,
#   436,
#   437,
#   49,
#   3,
#   438,
#   439,
#   52,
#   124,
#   440,
#   9,
#   441,
#   25,
#   2],
#  [7,
#   1,
#   435,
#   8,
#   3,
#   136,
#   4,
#   1,
#   436,
#   437,
#   49,
#   3,
#   438,
#   439,
#   52,
#   124,
#   440,
#   9,
#   441,
#   25,
#   2,
#   442],
#  [443, 1],
#  [443, 1, 28],
#  [443, 1, 28, 3],
#  [443, 1, 28, 3, 1],
#  [443, 1, 28, 3, 1, 5],
#  [443, 1, 28, 3, 1, 5, 137],
#  [443, 1, 28, 3, 1, 5, 137, 13],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65, 11],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65, 11, 31],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65, 11, 31, 3],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65, 11, 31, 3, 136],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65, 11, 31, 3, 136, 2],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65, 11, 31, 3, 136, 2, 444],
#  [443, 1, 28, 3, 1, 5, 137, 13, 65, 11, 31, 3, 136, 2, 444, 54],
#  [107, 445],
#  [107, 445, 1],
#  [107, 445, 1, 5],
#  [107, 445, 1, 5, 137],
#  [107, 445, 1, 5, 137, 2],
#  [107, 445, 1, 5, 137, 2, 446],
#  [107, 445, 1, 5, 137, 2, 446, 1],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448, 133],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448, 133, 131],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448, 133, 131, 449],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448, 133, 131, 449, 450],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448, 133, 131, 449, 450, 451],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448, 133, 131, 449, 450, 451, 27],
#  [107, 445, 1, 5, 137, 2, 446, 1, 447, 448, 133, 131, 449, 450, 451, 27, 452],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2,
#   135],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2,
#   135,
#   453],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2,
#   135,
#   453,
#   454],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2,
#   135,
#   453,
#   454,
#   455],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2,
#   135,
#   453,
#   454,
#   455,
#   4],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2,
#   135,
#   453,
#   454,
#   455,
#   4,
#   456],
#  [107,
#   445,
#   1,
#   5,
#   137,
#   2,
#   446,
#   1,
#   447,
#   448,
#   133,
#   131,
#   449,
#   450,
#   451,
#   27,
#   452,
#   54,
#   2,
#   135,
#   453,
#   454,
#   455,
#   4,
#   456,
#   457]]

# %%
max_len=max([len(x) for x in input_sequence])
print(max_len)
# Out:
# 32

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_seq=pad_sequences(input_sequence,maxlen=max_len,padding='pre')

# %%
x=padded_input_seq[:,:-1]
y=padded_input_seq[:,-1]

# %%
x.shape
# Out:
# (881, 31)

# %%
from tensorflow.keras.utils import to_categorical
y=to_categorical(y,num_classes=458)

# %%
y.shape
# Out:
# (881, 458)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model=Sequential()
model.add(Embedding(458,200,input_length=31))
model.add(LSTM(300))
# model.add(LSTM(150))
model.add(Dense(458,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 31, 200)           91600
#
#  lstm (LSTM)                 (None, 300)               601200
#
#  dense (Dense)               (None, 458)               137858
#
# =================================================================
# Total params: 830658 (3.17 MB)
# Trainable params: 830658 (3.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 7s 142ms/step - loss: 5.8928 - accuracy: 0.0715
# Epoch 2/100
# 28/28 [==============================] - 3s 111ms/step - loss: 5.4990 - accuracy: 0.0829
# Epoch 3/100
# 28/28 [==============================] - 1s 42ms/step - loss: 5.4027 - accuracy: 0.0897
# Epoch 4/100
# 28/28 [==============================] - 2s 57ms/step - loss: 5.3333 - accuracy: 0.1180
# Epoch 5/100
# 28/28 [==============================] - 1s 50ms/step - loss: 5.2079 - accuracy: 0.1407
# Epoch 6/100
# 28/28 [==============================] - 2s 61ms/step - loss: 5.0155 - accuracy: 0.1805
# Epoch 7/100
# 28/28 [==============================] - 1s 42ms/step - loss: 4.7655 - accuracy: 0.1884
# Epoch 8/100
# 28/28 [==============================] - 1s 24ms/step - loss: 4.4625 - accuracy: 0.2100
# Epoch 9/100
# 28/28 [==============================] - 0s 13ms/step - loss: 4.1205 - accuracy: 0.2327
# Epoch 10/100
# 28/28 [==============================] - 1s 29ms/step - loss: 3.7383 - accuracy: 0.2418
# Epoch 11/100
# 28/28 [==============================] - 0s 12ms/step - loss: 3.3624 - accuracy: 0.2985
# Epoch 12/100
# 28/28 [==============================] - 0s 12ms/step - loss: 2.9721 - accuracy: 0.3553
# Epoch 13/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.6117 - accuracy: 0.4086
# Epoch 14/100
# 28/28 [==============================] - 0s 12ms/step - loss: 2.2696 - accuracy: 0.5085
# Epoch 15/100
# 28/28 [==============================] - 0s 12ms/step - loss: 1.9585 - accuracy: 0.6073
# Epoch 16/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.6656 - accuracy: 0.7140
# Epoch 17/100
# 28/28 [==============================] - 0s 12ms/step - loss: 1.4171 - accuracy: 0.7809
# Epoch 18/100
# 28/28 [==============================] - 1s 17ms/step - loss: 1.2061 - accuracy: 0.8365
# Epoch 19/100
# 28/28 [==============================] - 0s 17ms/step - loss: 1.0205 - accuracy: 0.8774
# Epoch 20/100
# 28/28 [==============================] - 0s 12ms/step - loss: 0.8575 - accuracy: 0.9137
# Epoch 21/100
# 28/28 [==============================] - 0s 18ms/step - loss: 0.7358 - accuracy: 0.9205
# Epoch 22/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.6326 - accuracy: 0.9421
# Epoch 23/100
# 28/28 [==============================] - 0s 12ms/step - loss: 0.5498 - accuracy: 0.9489
# Epoch 24/100
# 28/28 [==============================] - 0s 12ms/step - loss: 0.4780 - accuracy: 0.9535
# Epoch 25/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4295 - accuracy: 0.9603
# Epoch 26/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3817 - accuracy: 0.9603
# Epoch 27/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3391 - accuracy: 0.9659
# Epoch 28/100
# 28/28 [==============================] - 0s 11ms/step - loss: 0.3015 - accuracy: 0.9682
# Epoch 29/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.2777 - accuracy: 0.9637
# Epoch 30/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.2540 - accuracy: 0.9694
# Epoch 31/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.2309 - accuracy: 0.9716
# Epoch 32/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2130 - accuracy: 0.9694
# Epoch 33/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2000 - accuracy: 0.9728
# Epoch 34/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.1832 - accuracy: 0.9739
# Epoch 35/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.1759 - accuracy: 0.9716
# Epoch 36/100
# 28/28 [==============================] - 1s 26ms/step - loss: 0.1646 - accuracy: 0.9728
# Epoch 37/100
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1528 - accuracy: 0.9750
# Epoch 38/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.1451 - accuracy: 0.9773
# Epoch 39/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.1408 - accuracy: 0.9750
# Epoch 40/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.1313 - accuracy: 0.9762
# Epoch 41/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.1275 - accuracy: 0.9750
# Epoch 42/100
# 28/28 [==============================] - 1s 14ms/step - loss: 0.1204 - accuracy: 0.9728
# Epoch 43/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.1145 - accuracy: 0.9762
# Epoch 44/100
# 28/28 [==============================] - 0s 12ms/step - loss: 0.1102 - accuracy: 0.9750
# Epoch 45/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.1066 - accuracy: 0.9762
# Epoch 46/100
# 28/28 [==============================] - 0s 12ms/step - loss: 0.1025 - accuracy: 0.9762
# Epoch 47/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.1013 - accuracy: 0.9773
# Epoch 48/100
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0979 - accuracy: 0.9773
# Epoch 49/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0958 - accuracy: 0.9762
# Epoch 50/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0932 - accuracy: 0.9716
# Epoch 51/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0916 - accuracy: 0.9773
# Epoch 52/100
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0914 - accuracy: 0.9773
# Epoch 53/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0875 - accuracy: 0.9750
# Epoch 54/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0845 - accuracy: 0.9728
# Epoch 55/100
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0824 - accuracy: 0.9773
# Epoch 56/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.9773
# Epoch 57/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9773
# Epoch 58/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0800 - accuracy: 0.9728
# Epoch 59/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0790 - accuracy: 0.9773
# Epoch 60/100
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0756 - accuracy: 0.9739
# Epoch 61/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0744 - accuracy: 0.9762
# Epoch 62/100
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0761 - accuracy: 0.9728
# Epoch 63/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 0.9762
# Epoch 64/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0733 - accuracy: 0.9784
# Epoch 65/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0697 - accuracy: 0.9750
# Epoch 66/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0722 - accuracy: 0.9773
# Epoch 67/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.9750
# Epoch 68/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0689 - accuracy: 0.9762
# Epoch 69/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0690 - accuracy: 0.9750
# Epoch 70/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0669 - accuracy: 0.9739
# Epoch 71/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0670 - accuracy: 0.9750
# Epoch 72/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0668 - accuracy: 0.9773
# Epoch 73/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0660 - accuracy: 0.9739
# Epoch 74/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0670 - accuracy: 0.9762
# Epoch 75/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0677 - accuracy: 0.9728
# Epoch 76/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0633 - accuracy: 0.9762
# Epoch 77/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0636 - accuracy: 0.9750
# Epoch 78/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0639 - accuracy: 0.9750
# Epoch 79/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0619 - accuracy: 0.9784
# Epoch 80/100
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0630 - accuracy: 0.9762
# Epoch 81/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0622 - accuracy: 0.9773
# Epoch 82/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0610 - accuracy: 0.9750
# Epoch 83/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0608 - accuracy: 0.9773
# Epoch 84/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0629 - accuracy: 0.9750
# Epoch 85/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0617 - accuracy: 0.9716
# Epoch 86/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0589 - accuracy: 0.9716
# Epoch 87/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0595 - accuracy: 0.9750
# Epoch 88/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0605 - accuracy: 0.9784
# Epoch 89/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0607 - accuracy: 0.9739
# Epoch 90/100
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0583 - accuracy: 0.9750
# Epoch 91/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0600 - accuracy: 0.9739
# Epoch 92/100
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0604 - accuracy: 0.9750
# Epoch 93/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9784
# Epoch 94/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0590 - accuracy: 0.9750
# Epoch 95/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 0.9762
# Epoch 96/100
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0580 - accuracy: 0.9762
# Epoch 97/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 0.9750
# Epoch 98/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0592 - accuracy: 0.9762
# Epoch 99/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0586 - accuracy: 0.9784
# Epoch 100/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 0.9762

# %%
import numpy as np
text=input("Enter: ")
for i in  range(10):
 token_text=tokenizer.texts_to_sequences([text])[0]
 padded_token_text=pad_sequences([token_text],maxlen=31,padding='pre')
 model.predict(padded_token_text)
 pos=np.argmax(model.predict(padded_token_text))
 for word,index in tokenizer.word_index.items():
   if index==pos:
     text=text+" "+word
     print(text)
# Out:
# Enter: work
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 17ms/step
# work science
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# work science the
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# work science the study
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# work science the study of
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# work science the study of the
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# work science the study of the earth's
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# work science the study of the earth's ecosystems
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# work science the study of the earth's ecosystems and
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# work science the study of the earth's ecosystems and the
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# work science the study of the earth's ecosystems and the impact
